# %% [markdown]
# # Sales Forecasting Example
#
# This notebook demonstrates how to use the sales forecasting pipeline for research and educational purposes.
#
# ## ⚠️ Important Disclaimer
#
# **This is a research and educational tool only.** Do not use these predictions for automated business decisions without human review.

# %%
import sys
from pathlib import Path

# Add src to path
sys.path.append(str(Path.cwd() / "src"))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px

from src.utils.config import Config
from src.forecasting.pipeline import SalesForecastingPipeline
from src.data.data_processor import DataProcessor
